# %%
import pandas as pd

# %%
df = pd.read_csv('data/raw/antihoax.csv')

# %%
df.status.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='status'>

# %%
from src.data import NewsDAO
NewsDAO.get_news_total_count()
# Out:
# 19987

# %%
len(df)
# Out:
# 19987

# %%
pd.set_option('display.max_colwidth', 3)
df.head()
# Out:
#       id authors status       classification  \
# 0  20234  36      Salah  False Context
# 1  20233  11      Salah  CekFakta
# 2  20232  36      Salah  Manipulated Content
# 3  20231  36      Salah  Fabricated Content
# 4  20230  36      Salah  Manipulated Content
#
#                                                                                                                           title  \
# 0  [SALAH] Detik-Detik Suntik Mati Ibu Baby Jailyn yang Meninggalkan Anaknya 10 Hari Hingga Meninggal
# 1  [HOAKS] Seorang Perempuan Jadi Korban Pembegalan di Baubau pada 28 Mei
# 2  [SALAH] Polisi Salah Tangkap Lagi, Egi Palsu Kembali Dilepaskan
# 3  [SALAH] Ferdy Sambo Selamat dari Hukuman Mati dan Sedang Liburan di Luar Negeri
# 4  [SALAH] Tangkapan Layar Judul Berita Detik: Prabowo Subianto siap terjunkan 80 Kopasus untuk penjagaan Kejagung Dan keluarga
#
# ...

# %%
pd.set_option('display.max_colwidth', None)
df[['content','fact']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
NewsDAO.get_news_list(1000, 0)
# Out:
# Fetching News: 100%|██████████| 1000/1000 [00:00<00:00, 199595.70it/s]
# [News(id=20234, title=[SALAH] Detik-Detik Suntik Mati Ibu Baby Jailyn yang Meninggalkan Anaknya 10 Hari Hingga Meninggal, status=Salah),
#  News(id=20233, title=[HOAKS] Seorang Perempuan Jadi Korban Pembegalan di Baubau pada 28 Mei, status=Salah),
#  News(id=20232, title=[SALAH] Polisi Salah Tangkap Lagi, Egi Palsu Kembali Dilepaskan, status=Salah),
#  News(id=20231, title=[SALAH] Ferdy Sambo Selamat dari Hukuman Mati dan Sedang Liburan di Luar Negeri, status=Salah),
#  News(id=20230, title=[SALAH] Tangkapan Layar Judul Berita Detik: Prabowo Subianto siap terjunkan 80 Kopasus untuk penjagaan Kejagung Dan keluarga, status=Salah),
#  News(id=20229, title=[SALAH] Video AI Lagu Baru Iwan Fals “Tikus & Macan”, status=Salah),
#  News(id=20228, title=[SALAH] Tangkapan Layar Berita Detik Jabar, Kemunculan hacker bjorka menanggapi kasus “Vina_Cirebon”, status=Salah),
# ...
